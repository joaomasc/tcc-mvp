# %% [markdown]
# # VS-ePL-KRLS — reprodução controlada
#
# Este notebook executa primeiro o fluxo sintético e depois, somente se `ANP_CSV` apontar para um arquivo real, o pipeline S10/S500.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks': ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
from examples.synthetic_regression import run_experiment
synthetic = run_experiment(output_dir=ROOT / 'reports/vs_epl_krls/notebook_synthetic', random_state=42)
synthetic

# %% [markdown]
# ## ANP
# Defina o caminho abaixo. A célula falha de modo explícito se o arquivo não existir; nenhum dado sintético é usado como substituto.

# %%
ANP_CSV = Path('CAMINHO/PARA/ANP.csv')
assert ANP_CSV.is_file(), 'Forneça um CSV real da ANP'
from vs_epl_krls import load_anp_fuel_csv, make_lagged_dataset
fuel = load_anp_fuel_csv(ANP_CSV)
lagged_h2 = make_lagged_dataset(fuel, horizon=2)
lagged_h4 = make_lagged_dataset(fuel, horizon=4)
fuel.groupby('product').agg(inicio=('date','min'), fim=('date','max'), n=('price','size'))
